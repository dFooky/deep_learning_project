# %%
import tensorflow as tf
from tensorflow import keras 
import tensorflow_datasets as tfds
from tensorflow.keras.preprocessing.text import Tokenizer
from bs4 import BeautifulSoup
import string

# %%
stopwords = ["a", "about", "above", "after", "again", "against", "all", "am", "an", "and", "any", "are", "as", "at",
             "be", "because", "been", "before", "being", "below", "between", "both", "but", "by", "could", "did", "do",
             "does", "doing", "down", "during", "each", "few", "for", "from", "further", "had", "has", "have", "having",
             "he", "hed", "hes", "her", "here", "heres", "hers", "herself", "him", "himself", "his", "how",
             "hows", "i", "id", "ill", "im", "ive", "if", "in", "into", "is", "it", "its", "itself",
             "lets", "me", "more", "most", "my", "myself", "nor", "of", "on", "once", "only", "or", "other", "ought",
             "our", "ours", "ourselves", "out", "over", "own", "same", "she", "shed", "shell", "shes", "should",
             "so", "some", "such", "than", "that", "thats", "the", "their", "theirs", "them", "themselves", "then",
             "there", "theres", "these", "they", "theyd", "theyll", "theyre", "theyve", "this", "those", "through",
             "to", "too", "under", "until", "up", "very", "was", "we", "wed", "well", "were", "weve", "were",
             "what", "whats", "when", "whens", "where", "wheres", "which", "while", "who", "whos", "whom", "why",
             "whys", "with", "would", "you", "youd", "youll", "youre", "youve", "your", "yours", "yourself",
             "yourselves"]

# %%
imdb_sentence=[]
table=str.maketrans('','',string.punctuation)
train_data=tfds.as_numpy(tfds.load('imdb_reviews',split='train'))
for item in train_data:
    sentence = str(item['text'].decode('UTF-8').lower())
    soup=BeautifulSoup(sentence)
    sentence = soup.get_text()
    words = sentence.split()
    filtered_sentence=''
    for word in words:
        if word not in stopwords:
            filtered_sentence=filtered_sentence+word+' '
    imdb_sentence.append(filtered_sentence)

# %%
tokenizer=Tokenizer(num_words=25000)
tokenizer.fit_on_texts(imdb_sentence)
sequences=tokenizer.texts_to_sequences(imdb_sentence)
print(tokenizer.word_index)
# Out:
# {'movie': 1, 'film': 2, 'not': 3, 'one': 4, 'like': 5, 'just': 6, "it's": 7, 'good': 8, 'it': 9, 'the': 10, 'no': 11, 'time': 12, 'even': 13, 'story': 14, 'really': 15, 'see': 16, 'can': 17, 'much': 18, 'get': 19, 'bad': 20, 'will': 21, 'also': 22, 'people': 23, 'first': 24, 'great': 25, "don't": 26, 'made': 27, 'way': 28, 'make': 29, 'movies': 30, 'think': 31, 'characters': 32, 'watch': 33, 'two': 34, 'films': 35, 'character': 36, 'seen': 37, 'many': 38, 'life': 39, 'plot': 40, 'never': 41, 'acting': 42, 'little': 43, 'best': 44, 'love': 45, 'show': 46, 'i': 47, 'know': 48, 'off': 49, 'ever': 50, 'this': 51, 'better': 52, 'end': 53, 'still': 54, 'man': 55, 'and': 56, 'say': 57, 'scene': 58, 'scenes': 59, 'go': 60, 'something': 61, 'back': 62, 'well': 63, "i'm": 64, 'real': 65, 'watching': 66, 'now': 67, 'though': 68, "doesn't": 69, 'years': 70, 'old': 71, 'thing': 72, 'actors': 73, 'work': 74, 'another': 75, "didn't": 76, 'new': 77, 'funny': 78, 'nothing': 79, '10': 80, 'actually': 81, 'makes': 82, 'director': 83, 'all': 84, 'look': 85, 'find': 86, 'going': 87, 'part': 88, 'every': 89, 'lot': 90, 'cast': 91, 'us': 92, 'quite': 93, 'want': 94, 'world': 95, 'things': 96, 'pretty': 97, 'young': 98, 'seems': 99, 'around': 100, 'got': 101, 'horror': 102, 'however': 103, "can't": 104, 'fact': 105, 'take': 106, 'that': 107, 'big': 108, 'enough': 109, 'long': 110, 'thought': 111, "that's": 112, 'series': 113, 'give': 114, 'may': 115, 'original': 116, 'action': 117, "i've": 118, 'right': 119, 'in': 120, 'without': 121, 'always': 122, 'times': 123, 'comedy': 124, 'point': 125, 'gets': 126, 'must': 127, 'come': 128, 'role': 129, "isn't": 130, 'saw': 131, 'almost': 132, 'interesting': 133, 'is': 134, 'least': 135, 'family': 136, 'done': 137, "there's": 138, 'whole': 139, 'bit': 140, 'music': 141, 'me': 142, 'script': 143, 'far': 144, 'a': 145, 'making': 146, 'anything': 147, 'guy': 148, 'minutes': 149, 'feel': 150, 'last': 151, 'since': 152, 'might': 153, 'performance': 154, "he's": 155, '2': 156, 'probably': 157, 'kind': 158, 'away': 159, 'but': 160, 'yet': 161, 'rather': 162, 'tv': 163, 'worst': 164, 'girl': 165, 'day': 166, 'sure': 167, 'fun': 168, 'hard': 169, 'woman': 170, 'played': 171, 'out': 172, 'found': 173, 'anyone': 174, 'on': 175, 'especially': 176, 'although': 177, 'there': 178, 'them': 179, 'course': 180, 'believe': 181, 'up': 182, 'comes': 183, 'looking': 184, 'him': 185, 'screen': 186, 'trying': 187, 'set': 188, 'so': 189, 'goes': 190, 'here': 191, 'looks': 192, 'place': 193, 'book': 194, 'different': 195, 'put': 196, 'ending': 197, 'money': 198, 'maybe': 199, 'true': 200, 'sense': 201, 'reason': 202, 'actor': 203, 'everything': 204, "wasn't": 205, 'shows': 206, 'dvd': 207, 'you': 208, 'three': 209, 'worth': 210, 'year': 211, 'job': 212, 'main': 213, 'together': 214, 'someone': 215, 'watched': 216, 'play': 217, 'again': 218, 'plays': 219, 'american': 220, 'said': 221, 'effects': 222, 'later': 223, 'takes': 224, 'instead': 225, '1': 226, 'seem': 227, 'beautiful': 228, 'john': 229, 'version': 230, 'audience': 231, 'high': 232, 'house': 233, 'night': 234, 'everyone': 235, 'left': 236, 'special': 237, 'seeing': 238, 'half': 239, 'excellent': 240, 'wife': 241, 'star': 242, 'shot': 243, 'war': 244, 'idea': 245, 'nice': 246, 'less': 247, 'black': 248, 'mind': 249, 'simply': 250, 'read': 251, 'second': 252, 'else': 253, "you're": 254, 'father': 255, 'fan': 256, 'poor': 257, 'help': 258, 'completely': 259, 'death': 260, 'used': 261, '3': 262, 'home': 263, 'either': 264, 'her': 265, 'short': 266, 'line': 267, 'given': 268, 'men': 269, 'dead': 270, 'top': 271, 'budget': 272, 'try': 273, 'performances': 274, 'wrong': 275, 'classic': 276, 'enjoy': 277, 'boring': 278, 'need': 279, 'rest': 280, 'use': 281, 'hollywood': 282, 'kids': 283, 'low': 284, 'production': 285, 'along': 286, 'full': 287, 'friends': 288, 'camera': 289, 'truly': 290, 'women': 291, 'as': 292, 'awful': 293, 'video': 294, 'next': 295, 'tell': 296, 'remember': 297, 'st ...

# %%
reverse_word_index=dict(
    [(value,key) for (key,value) in tokenizer.word_index.items()])
decoded_review=' '.join([reverse_word_index.get(i, '?') for i in sequences[0]])
print(decoded_review)
# Out:
# absolutely terrible movie don't lured christopher walken michael ironside great actors must simply worst role history even great acting not redeem movie's ridiculous storyline movie early nineties us propaganda piece pathetic scenes rebels making cases revolutions maria conchita alonso appeared phony pseudo love affair walken nothing pathetic emotional plug movie devoid real meaning disappointed movies like this ruining actor's like christopher walken's good name barely sit it
